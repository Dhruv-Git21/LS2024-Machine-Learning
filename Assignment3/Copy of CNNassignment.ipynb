# %% [markdown]
# # **CNN assignment**(Do read the note at the end)

# %% [markdown]
# Description: Here we are going to use CNN to classify images of elephants,tigers,cheetah's and crocodiles. Basically multiclass classificiation using CNN.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Q.1** Import all required modules

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
directory = '/content/drive/MyDrive/Assignment 3'

# %% [markdown]
# **Q.2** Load data using image_dataset_from_directory(https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory)

# %%
data=tf.keras.preprocessing.image_dataset_from_directory(
    directory,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=None,
    validation_split=None,
)
# Out:
# Found 1658 files belonging to 4 classes.

# %% [markdown]
# *   Since data object is not iterable,we will create a nummpy iterator for data.
# *   Then use batch to iterate through our data

# %%
data_iterator=data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %% [markdown]
# Run the below code and batch code 2-3 times to visualise the labels given to different animals.

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# **Q.3** Map the data such that all pixel values lie between 0 and 1 using the **lambda function**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.2),
    ]
)

# %%
data = data.map(lambda x, y: (x / 255, y))

# %% [markdown]
# **Q.4** Split the data into train set and test set(and validation set if needed) using **data.take**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-class-take-method/) and **data.skip**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-skip-method/)

# %%
#Your code here
total_batches = tf.data.experimental.cardinality(data).numpy()
train_batches = int(total_batches*0.90)
test_batches  = total_batches-train_batches

train_data = data.take(train_batches)
test_data = data.skip(train_batches).take(test_batches)

# %%
train_data = train_data.map(
    lambda x, y: (data_augmentation(x, training=True), y)
)

# %% [markdown]
# **Creating the model**

# %% [markdown]
# **Q.5** Write code to create CNN model including fully connected layers with softmax as final layer.

# %%
model= Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(256, 256, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(256, kernel_size=(3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(512, kernel_size=(1, 1), activation='relu'),
    BatchNormalization(),

    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    layers.Dropout(0.5),
    Dense(4, activation='softmax')
]
)

# %% [markdown]
# **Q.6** Compile your model

# %%
model.compile(optimizer = keras.optimizers.Adam(learning_rate = 0.001),loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %% [markdown]
# **Q.7** Fit your model with train set and make sure to keep **less epochs**(10-15) as the dataset size is very large.

# %%
model.fit(train_data,epochs = 50,verbose = 2)
# Out:
# Epoch 1/50
# 46/46 - 34s - loss: 2.1603 - accuracy: 0.4429 - 34s/epoch - 729ms/step
# Epoch 2/50
# 46/46 - 30s - loss: 1.3835 - accuracy: 0.5204 - 30s/epoch - 656ms/step
# Epoch 3/50
# 46/46 - 29s - loss: 1.1665 - accuracy: 0.5883 - 29s/epoch - 629ms/step
# Epoch 4/50
# 46/46 - 29s - loss: 1.0967 - accuracy: 0.6039 - 29s/epoch - 622ms/step
# Epoch 5/50
# 46/46 - 31s - loss: 1.0402 - accuracy: 0.6372 - 31s/epoch - 669ms/step
# Epoch 6/50
# 46/46 - 29s - loss: 0.9154 - accuracy: 0.6732 - 29s/epoch - 636ms/step
# Epoch 7/50
# 46/46 - 29s - loss: 0.8035 - accuracy: 0.6923 - 29s/epoch - 641ms/step
# Epoch 8/50
# 46/46 - 30s - loss: 0.7452 - accuracy: 0.7228 - 30s/epoch - 652ms/step
# Epoch 9/50
# 46/46 - 29s - loss: 0.6709 - accuracy: 0.7446 - 29s/epoch - 629ms/step
# Epoch 10/50
# 46/46 - 30s - loss: 0.6594 - accuracy: 0.7391 - 30s/epoch - 650ms/step
# Epoch 11/50
# 46/46 - 29s - loss: 0.5986 - accuracy: 0.7799 - 29s/epoch - 620ms/step
# Epoch 12/50
# 46/46 - 30s - loss: 0.6031 - accuracy: 0.7846 - 30s/epoch - 658ms/step
# Epoch 13/50
# 46/46 - 29s - loss: 0.5643 - accuracy: 0.7887 - 29s/epoch - 622ms/step
# Epoch 14/50
# 46/46 - 29s - loss: 0.5586 - accuracy: 0.8016 - 29s/epoch - 638ms/step
# Epoch 15/50
# 46/46 - 31s - loss: 0.4797 - accuracy: 0.8274 - 31s/epoch - 664ms/step
# Epoch 16/50
# 46/46 - 29s - loss: 0.5242 - accuracy: 0.8098 - 29s/epoch - 631ms/step
# Epoch 17/50
# 46/46 - 31s - loss: 0.4242 - accuracy: 0.8505 - 31s/epoch - 665ms/step
# Epoch 18/50
# 46/46 - 29s - loss: 0.4398 - accuracy: 0.8471 - 29s/epoch - 635ms/step
# Epoch 19/50
# 46/46 - 29s - loss: 0.4338 - accuracy: 0.8444 - 29s/epoch - 634ms/step
# Epoch 20/50
# 46/46 - 29s - loss: 0.4675 - accuracy: 0.8288 - 29s/epoch - 631ms/step
# Epoch 21/50
# 46/46 - 29s - loss: 0.3779 - accuracy: 0.8594 - 29s/epoch - 638ms/step
# Epoch 22/50
# 46/46 - 29s - loss: 0.3707 - accuracy: 0.8689 - 29s/epoch - 636ms/step
# Epoch 23/50
# 46/46 - 31s - loss: 0.3981 - accuracy: 0.8485 - 31s/epoch - 667ms/step
# Epoch 24/50
# 46/46 - 29s - loss: 0.3652 - accuracy: 0.8709 - 29s/epoch - 632ms/step
# Epoch 25/50
# 46/46 - 29s - loss: 0.3604 - accuracy: 0.8662 - 29s/epoch - 629ms/step
# Epoch 26/50
# 46/46 - 31s - loss: 0.3441 - accuracy: 0.8696 - 31s/epoch - 666ms/step
# Epoch 27/50
# 46/46 - 29s - loss: 0.3658 - accuracy: 0.8655 - 29s/epoch - 633ms/step
# Epoch 28/50
# 46/46 - 29s - loss: 0.3274 - accuracy: 0.8818 - 29s/epoch - 639ms/step
# Epoch 29/50
# 46/46 - 29s - loss: 0.3463 - accuracy: 0.8770 - 29s/epoch - 635ms/step
# Epoch 30/50
# 46/46 - 29s - loss: 0.3389 - accuracy: 0.8764 - 29s/epoch - 639ms/step
# Epoch 31/50
# 46/46 - 29s - loss: 0.3141 - accuracy: 0.8920 - 29s/epoch - 634ms/step
# Epoch 32/50
# 46/46 - 29s - loss: 0.3114 - accuracy: 0.8859 - 29s/epoch - 622ms/step
# Epoch 33/50
# 46/46 - 30s - loss: 0.2905 - accuracy: 0.8940 - 30s/epoch - 662ms/step
# Epoch 34/50
# 46/46 - 29s - loss: 0.3301 - accuracy: 0.8886 - 29s/epoch - 632ms/step
# Epoch 35/50
# 46/46 - 31s - loss: 0.2824 - accuracy: 0.8859 - 31s/epoch - 665ms/step
# Epoch 36/50
# 46/46 - 29s - loss: 0.3164 - accuracy: 0.8893 - 29s/epoch - 629ms/step
# Epoch 37/50
# 46/46 - 29s - loss: 0.2712 - accuracy: 0.9022 - 29s/epoch - 636ms/step
# Epoch 38/50
# 46/46 - 29s - loss: 0.2625 - accuracy: 0.8988 - 29s/epoch - 625ms/step
# Epoch 39/50
# 46/46 - 31s - loss: 0.2573 - accuracy: 0.9110 - 31s/epoch - 665ms/step
# Epoch 40/50
# 46/46 - 29s - loss: 0.2820 - accuracy: 0.8981 - 29s/epoch - 630ms/step
# Epoch 41/50
# 46/46 - 30s - loss: 0.2396 - accuracy: 0.9144 - 30s/epoch - 660ms/step
# Epoch 42/50
# 46/46 - 29s - loss: 0.2668 - accuracy: 0.9062 - 29s/epoch - 633ms/step
# Epoch 43/50
# 46/46 - 29s - loss: 0.2627 - accuracy: 0.9062 - 29s/epoch - 635ms/step
# Epoch 44/50
# 46/46 - 31s - loss: 0.2937 - accuracy: 0.9056 - 31s/epoch - 680ms/step
# Epoch 45/50
# 46/46 - 30s - loss: 0.2759 - accuracy: 0.8981 - 30s/epoch - 646ms/step
# Epoch 46/50
# 46/46 - 31s - loss: 0.2457 - accuracy: 0.9049 - 31s/epoch - 675ms/step
# Epoch 47/50
# 46/46 - 29s - loss: 0.2448 - accuracy: 0.9164 - 29s/epoch - 631ms/step
# Epoch 48/50
# 46/46 - 29s - loss: 0.2346 - accuracy: 0.9144 - 29s/epoch - 634ms/step
# Epoch 49/50
# 46/46 - 29s - loss: 0.2417 - accuracy: 0.9117 - 29s/epoch - 639ms/step
# Epoch 50/50
# 46/46 - 30s - loss: 0.1749 - accuracy: 0.9341 - 30s/epoch - 659ms/step

# %% [markdown]
# **Q.8** Test your code with test set

# %%
loss,accuracy=model.evaluate(test_data)
# Out:
# 6/6 [==============================] - 13s 187ms/step - loss: 0.3059 - accuracy: 0.8871

# %%
# Do not change this code
if accuracy>=0.85:
  print(f"Congratulations, CNN assignment complete!! Your accuracy is {accuracy}")
else:
  print(f"Try again, not enough accuracy! Your accuracy is {accuracy}" )
# Out:
# Congratulations, CNN assignment complete!! Your accuracy is 0.8870967626571655

# %% [markdown]
# **Note: 1. Many of you will get very high train accuracy but low test accuracy. This is called overfitting, this can be solved by increasing the train set size. If your getting low accuracy for both train and test, modify your layers in the model.**
#
# **2.Do use T4GPU.Ideally your first epoch will take quite sometime and rest of the epochs will be faster but if all your epochs are taking a lot of time, try starting a new gpu session(open a new gmail account and open colab on that) because your free gpu might have exhausted itself.**
#
# **3.Other than that everything should be fine, happy learning!!**
